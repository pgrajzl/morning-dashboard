# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

from src.fetch import get_index_data, get_prior_day_change
from src.plot import plot_index_performance

import pandas as pd

# %% [markdown]
# ___
# <h2 align="center">Index Performance</h2>
#
# ___

# %%
import src.fetch as fetch
plot_index_performance(fetch)
# Out:
# interactive(children=(Dropdown(description='Timeframe:', index=2, options=('1mo', '3mo', '6mo', 'ytd', '1y', '…

# %% [markdown]
# ___
# <h2 align="center">Sector Performance</h2>
#
# ___

# %%
import src.fetch as fetch
from src.plot import plot_sector_performance

plot_sector_performance(fetch)
# Out:
# interactive(children=(Dropdown(description='Timeframe:', index=5, options=('1d', '5d', '15d', '1mo', '3mo', '6…

# %% [markdown]
# ___
# <h2 align="center">Breadth</h2>
#
# ___

# %%
from src.plot import plot_rsp_spy_ratio, plot_market_breadth
plot_rsp_spy_ratio(fetch)
# Out:
# interactive(children=(Dropdown(description='Timeframe:', index=2, options=('1mo', '3mo', '6mo', 'ytd', '1y', '…

# %%
plot_market_breadth(fetch)
# Out:
# [*********************100%***********************]  503 of 503 completed

# %% [markdown]
# ___
# <h2 align="center">Yields</h2>
#
# ___

# %%
from src.plot import plot_yields
plot_yields(fetch)
# Out:
# interactive(children=(Dropdown(description='Timeframe:', index=2, options=('1mo', '3mo', '6mo', 'ytd', '1y', '…

# %% [markdown]
# ___
# <h2 align="center">Volatility</h2>
#
# ___

# %%
from src.plot import plot_volatility
plot_volatility(fetch)
# Out:
# interactive(children=(Dropdown(description='Timeframe:', index=2, options=('1mo', '3mo', '6mo', 'ytd', '1y', '…

# %%
raw = yf.download(["^VIX3M", "^VXEWZ"], period="1y", auto_adjust=True,
                   group_by="column", progress=False)
closes = raw["Close"]
print(closes.tail(15))
print(closes.isna().sum())
# Out:
# Ticker         ^VIX3M     ^VXEWZ
# Date
# 2026-06-29  19.530001  30.360001
# 2026-06-30  19.000000  29.389999
# 2026-07-01  19.160000  29.990000
# 2026-07-02  19.040001  30.080000
# 2026-07-06  18.780001  30.480000
# 2026-07-07  19.010000  29.900000
# 2026-07-08  19.459999  29.990000
# 2026-07-09  18.990000  29.139999
# 2026-07-10  18.570000  29.370001
# 2026-07-13  19.639999  30.040001
# 2026-07-14  19.299999  28.090000
# 2026-07-15  18.910000  27.760000
# 2026-07-16  19.500000  28.320000
# 2026-07-17  20.540001  29.320000
# 2026-09-10  19.730000  40.419998
# Ticker
# ^VIX3M    0
# ^VXEWZ    0
# dtype: int64
